# %%
import pandas as pd

# %%
#import the data from our csv
title_df = pd.read_csv('data.tsv', sep='\t',header=0)
# Out:
# C:\Users\sethb\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
title_df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#drop nas
title_df = title_df.dropna()

# %%
#drop original title column
title_df = title_df.drop(['originalTitle'], axis = 1)

# %%
title_df.head()
# Out:
#       tconst titleType            primaryTitle isAdult startYear endYear  \
# 0  tt0000001     short              Carmencita       0      1894      \N
# 1  tt0000002     short  Le clown et ses chiens       0      1892      \N
# 2  tt0000003     short          Pauvre Pierrot       0      1892      \N
# 3  tt0000004     short             Un bon bock       0      1892      \N
# 4  tt0000005     short        Blacksmith Scene       0      1893      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              4  Animation,Comedy,Romance
# 3             12           Animation,Short
# 4              1              Comedy,Short

# %%
#filter out adult films
non_adult = title_df[title_df['isAdult'] == 0]

# %%
#check the data
non_adult.head()
# Out:
#       tconst titleType            primaryTitle isAdult startYear endYear  \
# 0  tt0000001     short              Carmencita       0      1894      \N
# 1  tt0000002     short  Le clown et ses chiens       0      1892      \N
# 2  tt0000003     short          Pauvre Pierrot       0      1892      \N
# 3  tt0000004     short             Un bon bock       0      1892      \N
# 4  tt0000005     short        Blacksmith Scene       0      1893      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              4  Animation,Comedy,Romance
# 3             12           Animation,Short
# 4              1              Comedy,Short

# %%
#drop isAdult column
movie_df = non_adult.drop(['isAdult'], axis = 1)

# %%
#check the data
movie_df.head()
# Out:
#       tconst titleType            primaryTitle startYear endYear  \
# 0  tt0000001     short              Carmencita      1894      \N
# 1  tt0000002     short  Le clown et ses chiens      1892      \N
# 2  tt0000003     short          Pauvre Pierrot      1892      \N
# 3  tt0000004     short             Un bon bock      1892      \N
# 4  tt0000005     short        Blacksmith Scene      1893      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              4  Animation,Comedy,Romance
# 3             12           Animation,Short
# 4              1              Comedy,Short

# %%
#drop endYear column
movie_df = movie_df.drop(['endYear'], axis = 1)

# %%
#check the dat
movie_df.head(50)
# Out:
#        tconst titleType                                   primaryTitle  \
# 0   tt0000001     short                                     Carmencita
# 1   tt0000002     short                         Le clown et ses chiens
# 2   tt0000003     short                                 Pauvre Pierrot
# 3   tt0000004     short                                    Un bon bock
# 4   tt0000005     short                               Blacksmith Scene
# 5   tt0000006     short                              Chinese Opium Den
# 6   tt0000007     short    Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short         Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     movie                                     Miss Jerry
# 9   tt0000010     short                            Leaving the Factory
# 10  tt0000011     short                        Akrobatisches Potpourri
# 11  tt0000012     short                         The Arrival of a Train
# ...

# %%
#filter out all titleTypes other than movie
movie_df = movie_df[movie_df['titleType'] == 'movie']

# %%
#drop runtimMinutes that are \N
movie_df = movie_df[movie_df['runtimeMinutes'] != '\\N']

movie_df.head()
# Out:
#         tconst titleType                   primaryTitle startYear  \
# 8    tt0000009     movie                     Miss Jerry      1894
# 144  tt0000147     movie  The Corbett-Fitzsimmons Fight      1897
# 498  tt0000502     movie                       Bohemios      1905
# 570  tt0000574     movie    The Story of the Kelly Gang      1906
# 587  tt0000591     movie               The Prodigal Son      1907
#
#     runtimeMinutes                      genres
# 8               45                     Romance
# 144            100      Documentary,News,Sport
# 498            100                          \N
# 570             70  Action,Adventure,Biography
# 587             90                       Drama

# %%
#drop genres that are \N
movie_df = movie_df[movie_df['genres'] != '\\N']
movie_df.head()
# Out:
#         tconst titleType                    primaryTitle startYear  \
# 8    tt0000009     movie                      Miss Jerry      1894
# 144  tt0000147     movie   The Corbett-Fitzsimmons Fight      1897
# 570  tt0000574     movie     The Story of the Kelly Gang      1906
# 587  tt0000591     movie                The Prodigal Son      1907
# 672  tt0000679     movie  The Fairylogue and Radio-Plays      1908
#
#     runtimeMinutes                      genres
# 8               45                     Romance
# 144            100      Documentary,News,Sport
# 570             70  Action,Adventure,Biography
# 587             90                       Drama
# 672            120           Adventure,Fantasy

# %%
movie_df[['genre1', 'genre2', 'genre3']] = movie_df['genres'].str.split(',', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20992\3805161509.py in <module>
# ----> 1 m = movie_df[['genre1', 'genre2', 'genre3','genre4']] = movie_df['genres'].str.split(',', expand=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3598             self._setitem_frame(key, value)
#    3599         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
#    3602             self._set_item_frame_value(key, value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3637         else:
#    3638             if isinstance(value, DataFrame):
# -> 3639                 check_key_length(self.columns, key, value)
# ...

# %%
# Out:
#                    0          1          2
# 8            Romance       None       None
# 144      Documentary       News      Sport
# 570           Action  Adventure  Biography
# 587            Drama       None       None
# 672        Adventure    Fantasy       None
# ...              ...        ...        ...
# 9740186        Drama    History       None
# 9740270        Drama       None       None
# 9740311  Documentary       None       None
# 9740338  Documentary       None       None
# 9740370  Documentary       None       None
#
# [372818 rows x 3 columns]

# %%
#split up genres. Sourced from https://python.plainenglish.io/python-and-imdb-data-to-analyse-movie-genres-over-years-9577073e163b
#all_rec_df = [pd.DataFrame(row['tconst'],row['titleType'],row['primaryTitle'],row[startYear'],row['runtimeMinutes'],row['genres'].split(","))              
                    for _, row in movie_df.iterrows()]
#all_rec_df = pd.concat(all_rec_df).reset_index()
new_df =
# Out:
#   File "C:\Users\sethb\AppData\Local\Temp\ipykernel_20992\417283708.py", line 2
#     all_rec_df = [pd.DataFrame(row['tconst'],row['titleType'],row['primaryTitle'],row[startYear'],row['runtimeMinutes'],row['genres'].split(","))
#                                                                                                       ^
# SyntaxError: invalid syntax

# %%
all_rec_df.head()
# Out:
#          index     0
# 0      Romance  1894
# 1  Documentary  1897
# 2         News  1897
# 3        Sport  1897
# 4       Action  1906

# %%
all_rec_df.columns = ['genre','year']
all_rec_df['year'] = all_rec_df['year'].astype('str')
all_genres = all_rec_df

# %%
year_genre = pd.pivot_table(all_genres,  index=['year'], columns=['genre'], aggfunc= len,fill_value=0)

# %%
#year_genre.loc[:'2021']
year_genre['Total'] = year_genre.sum(axis = 1)
year_genre = year_genre.drop('\\N')
year_genre
# Out:
# genre  Action  Adult  Adventure  Animation  Biography  Comedy  Crime  \
# year
# 1894        0      0          0          0          0       0      0
# 1896        0      0          0          0          0       0      0
# 1897        0      0          0          0          0       0      0
# 1899        0      0          0          0          0       0      0
# 1900        0      0          0          0          0       0      0
# ...       ...    ...        ...        ...        ...     ...    ...
# 2023      307      0        150        104         93     659    214
# 2024        4      1          7          3          2       7      1
# 2025        3      0          2          2          0       2      0
# 2026        0      0          0          0          0       0      0
# 2029        0      0          2          0          0       0      0
#
# genre  Documentary  Drama  Family  ...  Reality-TV  Romance  Sci-Fi  Short  \
# year                               ...
# ...

# %%
movie_df.to_csv('title.csv', index = False)

# %%
dummies_df = pd.get_dummies(movie_df['genres'])

# %%
dummies_df.head()
# Out:
#      Action  Action,Adult,Crime  Action,Adventure  Action,Adventure,Animation  \
# 8         0                   0                 0                           0
# 144       0                   0                 0                           0
# 570       0                   0                 0                           0
# 587       0                   0                 0                           0
# 672       0                   0                 0                           0
#
#      Action,Adventure,Biography  Action,Adventure,Comedy  \
# 8                             0                        0
# 144                           0                        0
# 570                           1                        0
# 587                           0                        0
# 672                           0                        0
#
#      Action,Adventure,Crime  Action,Adventure,Documentary  \
# 8                         0                             0
# ...

# %%
dummies_df.to_csv('dummies.csv', index = False)

# %%
year_genre.to_csv('genre.csv',index = True)
